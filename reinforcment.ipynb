# %%
import pandas as pd
data={
      'Name':['Anish Rana','Mohit Kumar','Jai Sharma','Sujal Mehta','Kisore Kumar','Vishesh Jagir','Virat Kohli','Suraj Thakur','Vijay Sharma','Narender Modi'],
     'Marks':[89,45,30,78,67,99,23,65,13,100],
     'Result':['Pass','Fail','Fail','Pass','Pass','Pass','Fail','Pass','Fail','Pass']
 }

df=pd.DataFrame(data)
#print(df)

# Probability of Pass
prob_pass = len(df[df['Result']=='Pass'])/len(df)

print("Probability of Passing:", prob_pass)
